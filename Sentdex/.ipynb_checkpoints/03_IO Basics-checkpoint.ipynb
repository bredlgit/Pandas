# %%
import pandas as pd

# %%
df = pd.read_csv('ZILLOW-Z77006_ZRIFAH.csv')

# %%
df.head()
# Out:
#          Date  Value
# 0  2018-02-28  1.398
# 1  2018-01-31  1.388
# 2  2017-12-31  1.384
# 3  2017-11-30  1.380
# 4  2017-10-31  1.372

# %%
df.set_index('Date', inplace = True)

# %%
df.head()
# Out:
#             Value
# Date
# 2018-02-28  1.398
# 2018-01-31  1.388
# 2017-12-31  1.384
# 2017-11-30  1.380
# 2017-10-31  1.372

# %%
df.to_csv('austin_data.csv') # To write our data to a new CSV file

# %%
df.columns = ['Austin HPI']

# %%
df.head()
# Out:
#             Austin HPI
# Date
# 2018-02-28       1.398
# 2018-01-31       1.388
# 2017-12-31       1.384
# 2017-11-30       1.380
# 2017-10-31       1.372

# %%
df.to_csv('austin_data_03.csv', header=False)

# %% [markdown]
# ##### We are going to read back into pandas our file with no headers, so we set them with the names argument, and we also set the index to the date column

# %%
df02 = pd.read_csv('austin_data_03.csv', names = ['Date', 'Austin_HPI'], index_col = 0)

# %%
df02.head()
# Out:
#             Austin_HPI
# Date
# 2018-02-28       1.398
# 2018-01-31       1.388
# 2017-12-31       1.384
# 2017-11-30       1.380
# 2017-10-31       1.372

# %% [markdown]
# ##### Converting our dataframe to an html file

# %%
df02.to_html('example.html')

# %%
df.head()
# Out:
#             Austin HPI
# Date
# 2018-02-28       1.398
# 2018-01-31       1.388
# 2017-12-31       1.384
# 2017-11-30       1.380
# 2017-10-31       1.372

# %% [markdown]
# #### Renaming columns

# %%
df03 = pd.read_csv('austin_data_03.csv', names = ['Date', 'Austin_HPI'])

# %%
df03.head()
# Out:
#          Date  Austin_HPI
# 0  2018-02-28       1.398
# 1  2018-01-31       1.388
# 2  2017-12-31       1.384
# 3  2017-11-30       1.380
# 4  2017-10-31       1.372

# %%
df03.rename(columns={'Austin_HPI':'77006_HPI'})
# Out:
#           Date  77006_HPI
# 0   2018-02-28      1.398
# 1   2018-01-31      1.388
# 2   2017-12-31      1.384
# 3   2017-11-30      1.380
# 4   2017-10-31      1.372
# 5   2017-09-30      1.368
# 6   2017-08-31      1.370
# 7   2017-07-31      1.378
# 8   2017-06-30      1.390
# 9   2017-05-31      1.402
# 10  2017-04-30      1.412
# 11  2017-03-31      1.414
# 12  2017-02-28      1.408
# 13  2017-01-31      1.410
# 14  2016-12-31      1.420
# 15  2016-11-30      1.432
# 16  2016-10-31      1.444
# 17  2016-09-30      1.460
# 18  2016-08-31      1.480
# 19  2016-07-31      1.498
# 20  2016-06-30      1.510
# 21  2016-05-31      1.514
# 22  2016-04-30      1.510
# 23  2016-03-31      1.532
# 24  2016-02-29      1.548
# 25  2016-01-31      1.576
# 26  2015-12-31      1.576
# 27  2015-11-30      1.578
# 28  2015-10-31      1.578
# 29  2015-09-30      1.576
# ..         ...        ...
# 58  2013-04-30      1.302
# 59  2013-03-31      1.288
# 60  2013-02-28      1.268
# ...
