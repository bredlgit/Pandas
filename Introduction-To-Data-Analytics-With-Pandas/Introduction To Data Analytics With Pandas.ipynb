# %% [markdown]
# #### Key questions
# The dataset : total number of coffees made vs time.
#
# 1. Who are the main contributors to this dataset, and when are contributions generally made ?
# 2. What are the department's weekday coffee habits ?
# 3. How much coffee are people drinking ?

# %%
import pandas as pd
# %matplotlib inline
from IPython.display import Image

# %% [markdown]
# **Note : **
# The second line here tells matplotlib to plot directly under the cell where any plotting code is called. pandas uses matplotlib to generate graphs, and without this, the graphs would appear outside the Jupyter notebook when you called plt.show() - but we just want them to appear without having to do this.
#
# http://ipython.readthedocs.io/en/stable/interactive/plotting.html#id1

# %% [markdown]
# #### Importing the data
# Let's import the coffee data from CSV.

# %%
data = pd.read_csv('D:\Dataset\coffees.csv')

# %% [markdown]
# ** Note : **
# Pandas can read from many data formats : CSV, JSON, Excel, HDF5, SQL, and more.
#
# http://pandas.pydata.org/pandas-docs/version/0.20/io.html
#
# ###### What does the data look like?

# %%
data
# Out:
#                timestamp  coffees contributor
# 0    2011-10-03 08:22:00    397.0     Quentin
# 1    2011-10-04 11:48:00    410.0     Quentin
# 2    2011-10-05 07:02:00  testing     Anthony
# 3    2011-10-05 08:25:00      NaN     Quentin
# 4    2011-10-05 10:47:00    464.0     Quentin
# 5    2011-10-05 13:15:00    481.0     Quentin
# 6    2011-10-06 07:21:00    503.0     Anthony
# 7    2011-10-06 10:04:00    513.0     Quentin
# 8    2011-10-06 12:14:00    539.0        Mike
# 9    2011-10-06 12:49:00    540.0     Quentin
# 10   2011-10-06 14:52:00    563.0         Ben
# 11   2011-10-07 07:34:00    581.0     Anthony
# 12   2011-10-07 08:37:00    587.0     Quentin
# 13   2011-10-07 11:09:00    605.0     Quentin
# 14   2011-10-07 13:14:00    616.0        Mike
# 15   2011-10-07 14:10:00      NaN         Ben
# 16   2011-10-07 15:20:00    626.0      Mike M
# 17   2011-10-07 16:50:00    635.0      Mike M
# 18   2011-10-09 16:53:00    650.0        Colm
# ...

# %% [markdown]
# ###### Show me just the first few rows of the dataframe

# %%
data.head()
# Out:
#              timestamp  coffees contributor
# 0  2011-10-03 08:22:00    397.0     Quentin
# 1  2011-10-04 11:48:00    410.0     Quentin
# 2  2011-10-05 07:02:00  testing     Anthony
# 3  2011-10-05 08:25:00      NaN     Quentin
# 4  2011-10-05 10:47:00    464.0     Quentin

# %% [markdown]
# We have an index, and three columns : timestamp, coffees, and contributor.
#
# ###### Problems with our dataset
# 1. Why is there a string of text, testing, in our coffee numbers?
# 2. What's going on in the coffees column in the row after that?
#
# ** Note : **
# df.head(n=10) would show the first ten rows. The default is n=5.
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.head.html
#
# ###### Let's look at the string in the third row

# %%
# .loc or .iloc
data.loc[2]
# Out:
# timestamp      2011-10-05 07:02:00
# coffees                    testing
# contributor                Anthony
# Name: 2, dtype: object

# %% [markdown]
# Definitely a string. We'll note this as something to fix after we finish looking around.
#
# **Note : **
#
# **.loc** uses a label-based lookup, which means that the value you pass into the square brackets must be in the index.
#
# **.iloc** is integer-location-based, so .iloc[2] would return the third row. In this case, they're the same, but had we changed our index, as we'll see later, things would work differently.
#
# Indexing a dataframe with [] directly returns a pd.Series or pd.DataFrame by searching over columns, not rows. Indexing a pd.Series with [] is like indexing a dataframe with .iloc.
#
# https://pandas.pydata.org/pandas-docs/stable/indexing.html
#
# ###### We should also take a look at that NaN. In fact, let's look at the first five values in coffees.

# %%
# [] indexing on a series
data.coffees
# Out:
# 0        397.0
# 1        410.0
# 2      testing
# 3          NaN
# 4        464.0
# 5        481.0
# 6        503.0
# 7        513.0
# 8        539.0
# 9        540.0
# 10       563.0
# 11       581.0
# 12       587.0
# 13       605.0
# 14       616.0
# 15         NaN
# 16       626.0
# 17       635.0
# 18       650.0
# 19       656.0
# 20       673.0
# 21       694.0
# 22       699.0
# 23       713.0
# 24       770.0
# 25       790.0
# 26       799.0
# 27       805.0
# 28       818.0
# 29       819.0
#         ...
# 641        NaN
# 642        NaN
# 643    16195.0
# 644    16237.0
# 645    16257.0
# 646    16513.0
# 647    16659.0
# 648    16714.0
# 649    16891.0
# 650    16909.0
# 651    16977.0
# 652    17104.0
# 653        NaN
# 654    17165.0
# 655    17345.0
# 656    17354.0
# 657    17468.0
# 658    17489.0
# 659    17564.0
# 660    17789.0
# 661    17793.0
# 662    17824.0
# 663    17852.0
# 664    17868.0
# 665    18062.0
# 666    18235.0
# 667    18942.0
# 668    19698.0
# ...

# %% [markdown]
# **Note : **here, we're indexing a series ( a pd.Series object ). From a pd.DataFrame ( here, data ), when you access a single column (  data.coffees or data["coffees"] ), the object returned is a pd.Series. From that, indexing directly with [] works in an integer-location-based manner, and like with numpy arrays, you can take slices ( [:5] ).
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.html

# %%
data.coffees[:5] # To give us the first five elements in that series
# Out:
# 0      397.0
# 1      410.0
# 2    testing
# 3        NaN
# 4      464.0
# Name: coffees, dtype: object

# %% [markdown]
# ** Difference between a DataFrame and a Series** - A df contains multiple columns all or any of which can be viewed as a series
#
# ###### How long is the dataset?

# %%
print("Dataset length :")

# len()
print(len(data))
# Out:
# Dataset length :
# 671

# %%
# We could have used shape to get the same result but much quicker and easier
data.shape
# Out:
# (671, 3)

# %% [markdown]
# ** What else can we find out? **

# %%
# .describe() - We can use this to find out a number of things but as is
data.describe()
# Out:
#                   timestamp  coffees contributor
# count                   671      658         671
# unique                  671      654           9
# top     2011-10-25 17:52:00  12358.0     Quentin
# freq                      1        2         367

# %% [markdown]
# Looks like we also have some missing data - we have 671 rows, but the coffees column only has 658 entries.
#
# ** Note : ** .describe() returns different things based on what's in the dataframe, as we'll see later. For numerical columns, it will return things like the mean, standard deviation, and percentiles. For object columns ( strings or datetimes ), it will return the most frequent entry and the first and last items.
#
# For all columns, .describe() will return the count of objects in that column (not counting NaNs which is why coffees only shows 658 entries whereas timestamp and contibutor show 671 entries) and the unique number of entries. Theoretically, all of the timestamp data should be unique, hence 671 entries in the unique part and we can see that we have 9 different contributors.
#
# You can determine what's returned using .describe()'s keyword arguments.
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.describe.html
#
# ###### What to do with the missing data?
# We could drop those rows as they are not contributing anything or we could try to interpolate over the NaN's...we'll do both today.
#
# **Let's look at the dataframe where coffees is null.**

# %%
# .isnull() and boolean indexing with []
data.isnull() # We are looking for True(s) as this tells us that we are missing data
# Out:
#      timestamp  coffees  contributor
# 0        False    False        False
# 1        False    False        False
# 2        False    False        False
# 3        False     True        False
# 4        False    False        False
# 5        False    False        False
# 6        False    False        False
# 7        False    False        False
# 8        False    False        False
# 9        False    False        False
# 10       False    False        False
# 11       False    False        False
# 12       False    False        False
# 13       False    False        False
# 14       False    False        False
# 15       False     True        False
# 16       False    False        False
# 17       False    False        False
# 18       False    False        False
# 19       False    False        False
# 20       False    False        False
# 21       False    False        False
# 22       False    False        False
# 23       False    False        False
# ...

# %%
data['coffees'].isnull() # He may not like the brackets but I do
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 641     True
# 642     True
# 643    False
# 644    False
# 645    False
# 646    False
# 647    False
# 648    False
# 649    False
# 650    False
# 651    False
# 652    False
# 653     True
# 654    False
# 655    False
# 656    False
# 657    False
# 658    False
# 659    False
# 660    False
# 661    False
# 662    False
# 663    False
# 664    False
# 665    False
# 666    False
# 667    False
# 668    False
# 669    False
# 670    False
# Name: coffees, Length: 671, dtype: bool

# %% [markdown]
# **Note : **.isnull() returns a boolean array ( an array of Trues and Falses ), that you can then use to index the dataframe directly. Here, our boolean array tells us which entries in the coffees column are null, and we use that to index against the full dataframe - so we get back every column in the dataframe, but only those rows where coffees is null.
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.isnull.html

# %%
data[data['coffees'].isnull()] # Return to me the data where data.coffess isnull
# Out:
#                timestamp coffees contributor
# 3    2011-10-05 08:25:00     NaN     Quentin
# 15   2011-10-07 14:10:00     NaN         Ben
# 72   2011-10-28 10:53:00     NaN      Mike M
# 95   2011-11-11 11:13:00     NaN     Quentin
# 323  2012-06-10 16:10:00     NaN      Sergio
# 370  2012-07-13 13:59:00     NaN        Mike
# 394  2012-08-03 14:35:00     NaN      Sergio
# 479  2012-09-21 10:15:00     NaN      Sergio
# 562  2012-11-01 09:45:00     NaN     Quentin
# 606  2012-11-30 13:11:00     NaN     Quentin
# 641  2013-01-28 10:43:00     NaN      Sergio
# 642  2013-01-28 13:13:00     NaN     Quentin
# 653  2013-02-18 12:04:00     NaN     Quentin

# %% [markdown]
# i.e. return to me all the lines, from the coffees series, that have an NaN or missing value
#
# ###### What type of Python objects are the columns?
# Returning to the problem of the string in the coffees column

# %%
# .dtypes
data.dtypes # Returns the data types of all of my columns
# Out:
# timestamp      object
# coffees        object
# contributor    object
# dtype: object

# %% [markdown]
# The contributor column makes sense as object, because we expect strings there; but surely the timestamp should be a timestamp-type, and coffees should be numerical? We need the data to be in the correct format so that we can inspect it properly.
#
# **Let's inspect what is in the timestamp column.**

# %%
# print the first element of the series with [] indexing
print(data.timestamp[0])

# print its type()
print(type(data.timestamp[0]))
# Out:
# 2011-10-03 08:22:00
# <class 'str'>

# %% [markdown]
# It looks like the timestamp field was read from CSV as a string. That makes sense - CSV files are very basic. We'll have pandas interpret these strings as datetimes for us automatically.
#
# **Note :** here's an example of using direct [] indexing on a pd.Series. We're accessing the first entry, just to see what type of object we have there.
#
# On our first pass, what problems did we find?
# 1. The timestamp column contains strings; these need to be datetime objects
# 2. The coffees column contains some null values and at least one string

# %% [markdown]
# ### Cleaning the data
# **Problem One - The coffees column should only contain numerical data.**

# %%
# cast the coffees column using pd.to_numeric, and coerce errors
data.coffees = pd.to_numeric(data.coffees, errors = 'coerce')

data.head()
# Out:
#              timestamp  coffees contributor
# 0  2011-10-03 08:22:00    397.0     Quentin
# 1  2011-10-04 11:48:00    410.0     Quentin
# 2  2011-10-05 07:02:00      NaN     Anthony
# 3  2011-10-05 08:25:00      NaN     Quentin
# 4  2011-10-05 10:47:00    464.0     Quentin

# %% [markdown]
# If we tell Pandas to convert our column to numeric values only it will have a good go. (We use to_numeric first as it handles errors quite well.) The code above throws an error because we have a string, testing, in there and it cannot parse that. NaN values are ignored as they are actually valid elements<br>
# With ``errors = 'coerce' `` added to the command, we can tell Pandas to turn any errors into an NaN. The testing string is the only error that we have and it is safe to discard it as it doesn't provide any useful information...

# %%
data.dtypes
# Out:
# timestamp       object
# coffees        float64
# contributor     object
# dtype: object

# %% [markdown]
# We can see the to_numeric argument ran fine, we can see our df and when we check the data types of the different columns, we see that columns is now a float. We have some NaN's but we were expecting those.<br><br>
# **The coffees column contains NaN's.**<br>
# There are several ways to deal with these...<br>
# 1. We could pretend that they don't exist and just drop the rows<br>
# 2. You could fill in the rows, maybe by interpolating<br>
#     a. If you have a value above and below you could take the mean<br>
# 3. We could look at the time and date between two dates and wherever that value lies on that line, that is the value that we'll give it<br>
#     a.This is an interpolating between dates rather than two points that are equidistant<br><br>
# For now, we are going to use dropna()...

# %%
# Use .dropna() using a subset, and pass inplace
data.dropna(inplace = True) # Without inplace we would get a copy of the df which still had NaN's
#data = data.dropna() - Would work just as well
data.head()
# Out:
#              timestamp  coffees contributor
# 0  2011-10-03 08:22:00    397.0     Quentin
# 1  2011-10-04 11:48:00    410.0     Quentin
# 4  2011-10-05 10:47:00    464.0     Quentin
# 5  2011-10-05 13:15:00    481.0     Quentin
# 6  2011-10-06 07:21:00    503.0     Anthony

# %% [markdown]
# Using *<font color = blue>data = data.dropna()</font>* has the advantage of us losing the NaN's immediately as we are setting the Series with dropna() having been executed.<br><br>
# **The coffees column is of type float.**<br>
# We want this column to be integers

# %%
# Cast to int using .astype()
data.coffees = data.coffees.astype('int64')
data.head()
# Out:
#              timestamp  coffees contributor
# 0  2011-10-03 08:22:00      397     Quentin
# 1  2011-10-04 11:48:00      410     Quentin
# 4  2011-10-05 10:47:00      464     Quentin
# 5  2011-10-05 13:15:00      481     Quentin
# 6  2011-10-06 07:21:00      503     Anthony

# %%
data.coffees.dtype
# Out:
# dtype('int64')

# %%
data.dtypes
# Out:
# timestamp      object
# coffees         int64
# contributor    object
# dtype: object

# %% [markdown]
# **Let's have pandas parse the timestamp strings to datetime objects.**<br>
# We want to convert the timestamp column from strings(object) to a datetime object

# %%
# pd.to_datetime()
data.timestamp = pd.to_datetime(data.timestamp)

# Confirm dtypes
data.dtypes
# Out:
# timestamp      datetime64[ns]
# coffees                 int64
# contributor            object
# dtype: object

# %% [markdown]
# **So where do we stand?**

# %%
# .describe(), passing the include kwarg to see all information
data.describe()
# Out:
#             coffees
# count    657.000000
# mean    8568.471842
# std     4600.215049
# min      397.000000
# 25%     4986.000000
# 50%     9172.000000
# 75%    11562.000000
# max    24463.000000

# %% [markdown]
# We are only seeing the coffees column now because it is the only numeric column that we have left. (The others are datetime and object.) Pandas will always just show us the numeric values, in describe, when it has mixed data types in the df.<br>
# It is possible to get around this limitation and see everything tho...

# %%
data.describe(include = 'all') # Now we see the whole df
# Out:
#                   timestamp       coffees contributor
# count                   657    657.000000         657
# unique                  657           NaN           9
# top     2011-10-24 14:32:00           NaN     Quentin
# freq                      1           NaN         361
# first   2011-10-03 08:22:00           NaN         NaN
# last    2013-09-13 10:28:00           NaN         NaN
# mean                    NaN   8568.471842         NaN
# std                     NaN   4600.215049         NaN
# min                     NaN    397.000000         NaN
# 25%                     NaN   4986.000000         NaN
# 50%                     NaN   9172.000000         NaN
# 75%                     NaN  11562.000000         NaN
# max                     NaN  24463.000000         NaN

# %% [markdown]
# **Note :** *<font color = blue>.describe(include="all")</font>* is describing all attributes of all columns, but some don't make sense based on the column's dtype. For example, the contributor column has no first and last attributes, because those describe the first and last entries in an ordered series. That makes sense for the timestamp - those have an intuitive definition of sorting - but not so much for strings ( alphabetical order doesn't really matter when they're arbitrary strings ). Similary, the timestamp column has no mean or other numerical traits. What does it mean to calculate the mean timestamp ?<br><br>
# **The first five rows**

# %%
data.iloc[:5] # To show us the first five rows
# Out:
#             timestamp  coffees contributor
# 0 2011-10-03 08:22:00      397     Quentin
# 1 2011-10-04 11:48:00      410     Quentin
# 4 2011-10-05 10:47:00      464     Quentin
# 5 2011-10-05 13:15:00      481     Quentin
# 6 2011-10-06 07:21:00      503     Anthony

# %%
data[:5] # This works too
# Out:
#             timestamp  coffees contributor
# 0 2011-10-03 08:22:00      397     Quentin
# 1 2011-10-04 11:48:00      410     Quentin
# 4 2011-10-05 10:47:00      464     Quentin
# 5 2011-10-05 13:15:00      481     Quentin
# 6 2011-10-06 07:21:00      503     Anthony

# %%
data.head() # Is the one that we know and love
# Out:
#             timestamp  coffees contributor
# 0 2011-10-03 08:22:00      397     Quentin
# 1 2011-10-04 11:48:00      410     Quentin
# 4 2011-10-05 10:47:00      464     Quentin
# 5 2011-10-05 13:15:00      481     Quentin
# 6 2011-10-06 07:21:00      503     Anthony

# %% [markdown]
# ### The time-series at a glance<br>
# **Let's begin by visualising the coffee counts.**

# %%
# .plot() on the coffees series
data.coffees.plot()

# %% [markdown]
# pandas is plotting the coffees against the index, which is just a series of integers. It is not taking into account the distance between datetimes
#
# **Note :** .plot() on a pd.Series will plot the data against the index. On a pd.DataFrame, the .plot() method allows plotting of one column against another.
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.plot.html
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html
#
# By default, .plot() renders a line graph, but you can specify which type of plot you'd like - bar, line, histogram, area, scatter, etc..

# %% [markdown]
# **Let's use the dataframe's plot() method rather than that of the series.**<br>
# If we do this, we can pass in the index

# %%
# .plot() on the dataframe, pass x to plot against the timestamp, use a dot-dash style
# data.plot(x = data.timestamp, style = ".-") # Got a huge error when I tried to plot this

# %% [markdown]
# **We'll inspect the last few points of this time-series.**

# %%
# .tail() with ten rows
data.tail(n=10)
# Out:
#               timestamp  coffees contributor
# 661 2013-03-04 11:12:00    17793     Quentin
# 662 2013-03-04 16:43:00    17824     Quentin
# 663 2013-03-05 10:42:00    17852     Quentin
# 664 2013-03-05 13:29:00    17868     Quentin
# 665 2013-03-08 10:28:00    18062     Quentin
# 666 2013-03-12 08:28:00    18235      Sergio
# 667 2013-04-05 11:20:00    18942      Sergio
# 668 2013-04-27 11:04:00    19698      Sergio
# 669 2013-09-12 15:38:00    24450     Quentin
# 670 2013-09-13 10:28:00    24463     Quentin

# %% [markdown]
# After mid-March, things start getting spaced rather erratically.<br><br>
# **Let's cut off the tail of the time-series, anything after 01-03-2013**

# %%
# Use conditional indexing against the timestamp
data = data[data.timestamp < "2013-03-01"]

data.tail()
# Out:
#               timestamp  coffees contributor
# 655 2013-02-21 13:44:00    17345     Quentin
# 656 2013-02-21 15:02:00    17354     Quentin
# 657 2013-02-25 13:33:00    17468     Quentin
# 658 2013-02-25 17:25:00    17489     Quentin
# 659 2013-02-27 09:33:00    17564     Quentin

# %% [markdown]
#  - ``data.timestamp < "2013-03-01`` - Gives us a series of Trues/Falses based on whetherthe data is before 1st March 2013 or not<br>
#  - If we look at the tail of that, it ends on 27 February 2013, so nothing from the 1 March 2013 or after<br>
#  - The whole command says that the new data is the old data minus anything from after 1 March 2013<br>
#  - Again, the tail shows no values after 27 Feb 2013, so we have successfully lost all the data after February<br><br>

# %% [markdown]
# **Note :** this is another example of boolean indexing. data.timestamp < "2013-03-01" is a boolean array, and can be passed into the dataframe immediately in [], much like with a np.ndarray.<br><br>
# **One final look**

# %%
# Once again, plot the data against the timestamp
# data.plot(x=data.timestamp, style=".-") - This didn't work before and doesn't work now either

# %% [markdown]
# ## 1. Contributions to the time-series
# **Who are our main contributors?**

# %%
# .value_counts()
data.contributor.value_counts()
# Out:
# Quentin    354
# Mike       152
# Sergio      89
# Mike M      29
# Colm        12
# Anthony      4
# Ben          3
# Stefano      2
# Arturo       1
# Name: contributor, dtype: int64

# %% [markdown]
# Indexed by the unique values in the series, in this case the names of the dept., and then it counts the number of times that the unique value occurs. This could easily be the names of the continents in our countries dataset or something similar<br><br>
# **Note :** .value_counts() counts the unique values in a series. It's similar to doing a .groupby() followed by a .count(), as we'll see soon.<br>
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html<br><br>
# **Let's plot this**

# %%
# .plot() a bar chart from the value counts
data.contributor.value_counts().plot(kind="bar")

# %% [markdown]
# **Note: **No x value required as when you plot against a Series it plots against the index of the Series which is the names of the contributors

# %% [markdown]
# **On which weekdays were contributions made?**<br>
# Because the timestamp column is a datetime column, it opens up a whole new set of functions that we can use that are all date related. The one that we are using here is dt, or datetime, and we are using that to determine the days of the week that the contributions were made

# %%
# Create a series of the weekdays for each entry using .dt.weekday
weekdays = data.timestamp.dt.weekday
weekdays # Shows us the days of the week that coffee was made in the machine with zero being Monday
# Out:
# 0      0
# 1      1
# 4      2
# 5      2
# 6      3
# 7      3
# 8      3
# 9      3
# 10     3
# 11     4
# 12     4
# 13     4
# 14     4
# 16     4
# 17     4
# 18     6
# 19     0
# 20     0
# 21     0
# 22     0
# 23     0
# 24     1
# 25     2
# 26     2
# 27     2
# 28     2
# 29     2
# 30     2
# 31     3
# 32     3
#       ..
# 627    1
# 628    1
# 629    4
# 630    1
# 631    2
# 632    3
# 633    4
# 634    4
# 635    4
# 636    1
# 637    2
# 638    2
# 639    3
# 640    0
# 643    0
# 644    1
# 645    1
# 646    0
# 647    2
# 648    3
# 649    1
# 650    1
# 651    2
# 652    5
# 654    0
# 655    3
# 656    3
# 657    0
# 658    0
# 659    2
# Name: timestamp, Length: 646, dtype: int64

# %%
# assign() it to our dataframe
data = data.assign(weekdays=weekdays)
#The weekdays column is going to be the weekdays object that we just created
data.head()
# Out:
#             timestamp  coffees contributor  weekdays
# 0 2011-10-03 08:22:00      397     Quentin         0
# 1 2011-10-04 11:48:00      410     Quentin         1
# 4 2011-10-05 10:47:00      464     Quentin         2
# 5 2011-10-05 13:15:00      481     Quentin         2
# 6 2011-10-06 07:21:00      503     Anthony         3

# %% [markdown]
# **df.assign - New way to create a new column in the df**<br>
# For more information, visit - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.assign.html<br>
# **Note:** df.assign takes a copy, rather than a view, and adds the new column to the df. This may or may not cause issues later on.<br>
# For more information, visit - http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# **Can we replace these integers with actual weekdays?**
# While it is great to be able to pull out the 0-6 notation, it is not very helpful when it comes to days of the week especially as there is a much simpler way of recording these. A way that everyone understands...

# %%
weekday_names = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
weekday_dict = {key: weekday_names[key] for key in range(7)}

# %% [markdown]
#  - weekday_names - A list of the days of the week
#  - weekday_dict - A mapping of the days of the week to the numbers 0-6 (range(7))
#  - Then we iterate through them

# %% [markdown]
# Use .apply() to apply a custom function to the weekdays column...This code was on the github...
# ``data.weekdays = data.weekdays.apply(lambda x: weekday_dict[x]) `` but, in the video, he actually used something completely different.<br>
# **lambda functions** - Here is an anonymous function, don't bother giving it a name just apply it<br>
# For more information, visit - https://www.programiz.com/python-programming/anonymous-function

# %% [markdown]
# **What did he actually use**

# %%
def day_of_week(idx):
    return weekday_dict[idx]
day_of_week(0)
# Out:
# 'Monday'

# %%
day_of_week(2)
# Out:
# 'Wednesday'

# %% [markdown]
# First we defined our function and made sure that it worked and brough back the expected results. Then we applied it to the weekdays column/Series of our data df...

# %%
data.weekdays = data.weekdays.apply(day_of_week)
data.head()
# Out:
#             timestamp  coffees contributor   weekdays
# 0 2011-10-03 08:22:00      397     Quentin     Monday
# 1 2011-10-04 11:48:00      410     Quentin    Tuesday
# 4 2011-10-05 10:47:00      464     Quentin  Wednesday
# 5 2011-10-05 13:15:00      481     Quentin  Wednesday
# 6 2011-10-06 07:21:00      503     Anthony   Thursday

# %% [markdown]
# Now, we see that our weekdays columns actually returns the days of the week in a format that we can all understand<br><br>
# **Let's group by these weekdays.**<br>
# The original question was, on which days are people contributing...

# %%
# .groupby() the weekdays and then .count() rows in each group
weekday_counts = data.groupby("weekdays").count()

weekday_counts
# Out:
#            timestamp  coffees  contributor
# weekdays
# Friday           114      114          114
# Monday           145      145          145
# Saturday          29       29           29
# Sunday            13       13           13
# Thursday         117      117          117
# Tuesday           97       97           97
# Wednesday        131      131          131

# %% [markdown]
# We are taking the df and using .groupby at the weekdays column to group those entries into the Monday (etc) groups and then count them up<br>
# What .groupby() does is that it takes all the Mondays together and counts them, and it will do that for every unique entry in weekdays column(when we point it at that column).<br><br>
# **Note:** this first line could be replaced by weekday_counts = data.weekdays.value_counts(), with the only difference being that that would return a series to us, and here, we got back a dataframe.

# %%
# We can reorder this dataframe by our weekday_names list
weekday_counts = weekday_counts.loc[weekday_names]
weekday_counts
# Out:
#            timestamp  coffees  contributor
# weekdays
# Monday           145      145          145
# Tuesday           97       97           97
# Wednesday        131      131          131
# Thursday         117      117          117
# Friday           114      114          114
# Saturday          29       29           29
# Sunday            13       13           13

# %% [markdown]
# **We can now visualise these weekday counts**

# %%
# .plot() a bar chart of data in weekday_counts
weekday_counts.timestamp.plot(kind="bar", title="Datapoints added on each weekday")

# %% [markdown]
# The original code looked like this. This is because we have three columns which all show the same information. As we do not need the same information represented three times, we picked a column to plot, it really doesn't matter which one as they all have the same data, and we got the ploty above.

# %%
weekday_counts.plot(kind="bar", title="Datapoints added on each weekday")

# %% [markdown]
# ## 2. Weekday Trends
# The above plot shows us when people input data ie we were counting the rows but now we want to count the difference in coffees between each row. We want to know on which day are people consuming the most coffee.
#
# #### First, we'll set our timestamps to the dataframe's index

# %%
# Set the dataframe's .index property
data.index = data.timestamp

data.head()
# Out:
#                               timestamp  coffees contributor   weekdays
# timestamp
# 2011-10-03 08:22:00 2011-10-03 08:22:00      397     Quentin     Monday
# 2011-10-04 11:48:00 2011-10-04 11:48:00      410     Quentin    Tuesday
# 2011-10-05 10:47:00 2011-10-05 10:47:00      464     Quentin  Wednesday
# 2011-10-05 13:15:00 2011-10-05 13:15:00      481     Quentin  Wednesday
# 2011-10-06 07:21:00 2011-10-06 07:21:00      503     Anthony   Thursday

# %% [markdown]
# What does our df look like now?..<br>
# - We have just replaced our index with a datetime index object that Pandas created for us.
# - We now have dates for our index, these aren't strings anymore because we converted them to datetime object
# - We have the timestaqmp column which contains the exact same information as our index...do we need this anymore?
# - The coffees, the contributor and the weekday that the information was entered in on
#
# **Let's drop the timestamp column, as we no longer need it**<br>
# - We are going to use ``.drop()`` to get rid of the uneeded timestamp column

# %%
data.drop(["timestamp"], axis=1, inplace=True)
data.head() # Our timestamp column has gone but not the one that is being used as the index
# Out:
#                      coffees contributor   weekdays
# timestamp
# 2011-10-03 08:22:00      397     Quentin     Monday
# 2011-10-04 11:48:00      410     Quentin    Tuesday
# 2011-10-05 10:47:00      464     Quentin  Wednesday
# 2011-10-05 13:15:00      481     Quentin  Wednesday
# 2011-10-06 07:21:00      503     Anthony   Thursday

# %% [markdown]
# - Usually ``.drop`` looks in the index, ``axis = 0 ``to drop stuff so we have to pass it the ``axis = 1`` argument so that it knows that we want to drop a column
# - A df cannot exist without an index
#     - To get the timestamp as the index we had to copy it over
#     - Now that it is in place, we can drop the timestamp column which is not an index so we can get rid of it

# %% [markdown]
# #### Let's add some rows at midnight on every day.
# We want to get one value per day, to do this we are going to add one row, everyday at midnight and finding the value of the number of coffees at that time and then dropping my rows that are not at midnight.
#
# We are going to create a new index but this one will live outside of the df(!?)

# %%
# pd.date_range, with daily frequency, and normalisation
midnights = pd.date_range(data.index[0], data.index[-1], freq="D", normalize=True)

midnights
# Out:
# DatetimeIndex(['2011-10-03', '2011-10-04', '2011-10-05', '2011-10-06',
#                '2011-10-07', '2011-10-08', '2011-10-09', '2011-10-10',
#                '2011-10-11', '2011-10-12',
#                ...
#                '2013-02-18', '2013-02-19', '2013-02-20', '2013-02-21',
#                '2013-02-22', '2013-02-23', '2013-02-24', '2013-02-25',
#                '2013-02-26', '2013-02-27'],
#               dtype='datetime64[ns]', length=514, freq='D')

# %% [markdown]
# ``pd.date_range()`` - We are going to use the date range method to create a new date range<br>
# ``data.index[0]`` - It is going to start at the first value in the index<br>
# ``data.index[-1]`` - It is going to end at the last entry in the index<br>
# ``freq="D"`` - This sets the frequency to days
#         - We could have entries for weeks, 'W', months 'M' etc etc etc<br>
# ``normalize=True`` - Make these datapoints at midnight<br><br>
#
# More information about the Pandas date_range() function can be accessed [here.](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.date_range.html)
#
# These datetime objects no longer have a time, there ius just one a day, everyday, from the start of the df everyday to the end.
#
# So we have this index of days and in our df we have an index that is randomly spaced. There are some indices that have uniformly spaced points which are all very neat but, at the moment, our index does not look like that...that's what our new index is for.
#
# We are going to create a new index that takes the union of both of these.
#
# #### Let's take the union of this index and our dataset's index.

# %%
# Take the union of the existing and new indices
new_index = midnights.union(data.index)

new_index
# Out:
# DatetimeIndex(['2011-10-03 00:00:00', '2011-10-03 08:22:00',
#                '2011-10-04 00:00:00', '2011-10-04 11:48:00',
#                '2011-10-05 00:00:00', '2011-10-05 10:47:00',
#                '2011-10-05 13:15:00', '2011-10-06 00:00:00',
#                '2011-10-06 07:21:00', '2011-10-06 10:04:00',
#                ...
#                '2013-02-21 15:02:00', '2013-02-22 00:00:00',
#                '2013-02-23 00:00:00', '2013-02-24 00:00:00',
#                '2013-02-25 00:00:00', '2013-02-25 13:33:00',
#                '2013-02-25 17:25:00', '2013-02-26 00:00:00',
#                '2013-02-27 00:00:00', '2013-02-27 09:33:00'],
#               dtype='datetime64[ns]', length=1160, freq=None)

# %% [markdown]
# ``midgnights`` - This is the index that we created for one value at midnight everyday. It lives outside of the df<br>
# ``.union()`` - Join our two two values together<br>
# ``data.index`` - Is the current index of our df
#
# This code instructs Python/Pandas to come up with a new index that has the values of both of these indices together in one index  and make sure that it is sorted in order<br>
# **Note :** the union of these indices is just a new index where entries from both indices are present. It's sorted by time.
#
# #### Now we can re-index our dataframe with this new index

# %%
# .reindex() the dataframe
upsampled_data = data.reindex(new_index)

upsampled_data.head(10)
# Out:
#                      coffees contributor   weekdays
# 2011-10-03 00:00:00      NaN         NaN        NaN
# 2011-10-03 08:22:00    397.0     Quentin     Monday
# 2011-10-04 00:00:00      NaN         NaN        NaN
# 2011-10-04 11:48:00    410.0     Quentin    Tuesday
# 2011-10-05 00:00:00      NaN         NaN        NaN
# 2011-10-05 10:47:00    464.0     Quentin  Wednesday
# 2011-10-05 13:15:00    481.0     Quentin  Wednesday
# 2011-10-06 00:00:00      NaN         NaN        NaN
# 2011-10-06 07:21:00    503.0     Anthony   Thursday
# 2011-10-06 10:04:00    513.0     Quentin   Thursday

# %% [markdown]
# We can see that now that the two indices have been merged we have no data for the midnight index entries. Pandas doesn't fill in any data for us, it just fills in the missing data with 'I don't knows' or NaN's. For all the NaN's in the coffee column, we want them to have a value, it will be somewhere between the entries for that day and the midnight entry for the following day eg the first value that we have to fill in is something between 08:22 on 03/10/2011 and midnight on 04/10/2011.
#
# **Note :** `.reindex()` - keeps any values that conform to the new index, and inserts `NaN`s where we have no values. More information on the ``reindex()`` function can be found [at](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.reindex.html)

# %% [markdown]
# #### We can fill in these `NaN`s using interpolation
# We could use ``.fillna('any_value')`` to set all the ``NaN``'s to a specific value but this is rather a blunt instrument and doesn't really help us. We could also have used the ``.fillna(ffill)`` & ``.fillna(bfill)`` methods but while these are a bit more subtle than they do not really help us either.
#
# Interpolation - If I have a number of points and then one point that I do not know what its value is, we can look at the points to the left and right and...
# - Linear Interpolation - We just take an average of the two points and make our unknown value that average
#     - This is a pretty simple example of interpolation
#     - This is ok if I am equally spaced between all of my points but our df index is not like that
# - Interpolation Against Time - ie plot this against the time axis and, wherever the line is, take that value instead
#     - This will be between the value befor and the value after
#     - ...but it might be closer to the value after if the time that I'm sampling is closer to the value after

# %%
# .interpolate the upsampled_data using the time method
upsampled_data = upsampled_data.interpolate(method="time")

upsampled_data.head(10)
# Out:
#                         coffees contributor   weekdays
# 2011-10-03 00:00:00         NaN         NaN        NaN
# 2011-10-03 08:22:00  397.000000     Quentin     Monday
# 2011-10-04 00:00:00  404.408262         NaN        NaN
# 2011-10-04 11:48:00  410.000000     Quentin    Tuesday
# 2011-10-05 00:00:00  438.664249         NaN        NaN
# 2011-10-05 10:47:00  464.000000     Quentin  Wednesday
# 2011-10-05 13:15:00  481.000000     Quentin  Wednesday
# 2011-10-06 00:00:00  494.066298         NaN        NaN
# 2011-10-06 07:21:00  503.000000     Anthony   Thursday
# 2011-10-06 10:04:00  513.000000     Quentin   Thursday

# %% [markdown]
# - All the midnight values have now been filled in by pandas using the interpolate method.
# - We do get some odd numbers eg 404.408 but this is the number interpolated between the time before and after by Pandas
#     - This number is actually higher than the average of the two numbers either side of it
#     - That's because midnight is closer to the following value than it is to the previous value therefore, the number is closer to the value following

# %% [markdown]
# #### We're now ready to resample the time-series at a daily frequency.

# %%
# .resample() followed by .asfreq()
daily_data = upsampled_data.resample("D")
#'D' is for daily
daily_data
# Out:
# DatetimeIndexResampler [freq=<Day>, axis=0, closed=left, label=left, convention=start, base=0]

# %% [markdown]
# This is a DateTimeIndexResampler & it actually looks like ``groupby()`` object. Like a ``groupby()`` object it mashes some things together but it doesn't really gives us any information<br>
# This says, look at the timestamps and group everything into days, if n rows are in the same day then put them in the same group but we haven't told it what to do with the group yet. We could do several things...<br>
# - We could take the mean of all the bins(?) in the group...
#     - ``daily_data = upsampled_data.resample("D").mean()``
# - I could take the count of everything in the group...
#     - ``daily_data = upsampled_data.resample("D").count()``
# - What we are actually gonna do is to say asfreq()...
#     - Which basically says, resample daily and only take the midnights from that day
#     - As we have inferred the values at those midnights, we get a number for the whole group at midnight

# %%
daily_data = upsampled_data.resample("D").asfreq()
daily_data
#You can use the on argument to resample on a column
# Out:
#                  coffees contributor weekdays
# 2011-10-03           NaN         NaN      NaN
# 2011-10-04    404.408262         NaN      NaN
# 2011-10-05    438.664249         NaN      NaN
# 2011-10-06    494.066298         NaN      NaN
# 2011-10-07    572.844311         NaN      NaN
# 2011-10-08    637.237253         NaN      NaN
# 2011-10-09    644.729448         NaN      NaN
# 2011-10-10    652.924658         NaN      NaN
# 2011-10-11    734.573206         NaN      NaN
# 2011-10-12    780.924214         NaN      NaN
# 2011-10-13    852.178510         NaN      NaN
# 2011-10-14    928.236328         NaN      NaN
# 2011-10-15    979.434976         NaN      NaN
# 2011-10-16    992.632896         NaN      NaN
# 2011-10-17   1005.830815         NaN      NaN
# 2011-10-18   1057.727273         NaN      NaN
# 2011-10-19   1115.727273         NaN      NaN
# 2011-10-20   1214.806107         NaN      NaN
# 2011-10-21   1275.159821         NaN      NaN
# ...

# %% [markdown]
# We have lost the time information in our index but we don't need it anymore because everything is equally spaced one day apart
#
# We still have a weekdays and a contributors column which we do not need anymore...the reason that we do not need them is that they are full of NaNs, they do not contain any information. However, we are only going to drop the contributor column...

# %%
# Drop the contributor column, we no longer need it
daily_data = daily_data.drop(["contributor"], axis=1)
daily_data.head()
# Out:
#                coffees weekdays
# 2011-10-03         NaN      NaN
# 2011-10-04  404.408262      NaN
# 2011-10-05  438.664249      NaN
# 2011-10-06  494.066298      NaN
# 2011-10-07  572.844311      NaN

# %% [markdown]
# We can see that the contributor column has been dropped

# %%
# Generate a column of weekday names
daily_data["weekdays"] = daily_data.index.weekday_name  # We did it the slow way before...
daily_data.head()
# Out:
#                coffees   weekdays
# 2011-10-03         NaN     Monday
# 2011-10-04  404.408262    Tuesday
# 2011-10-05  438.664249  Wednesday
# 2011-10-06  494.066298   Thursday
# 2011-10-07  572.844311     Friday

# %% [markdown]
# This is the easier way to get the weekdays into our df, see above for the more difficult way.
#
# What we have done is taken the weekdays column and set it as the ``df.index.weekday_name``. You take the index, which is a list of dates and you say what's the day of the week for each of those and so we have that information back.
#
# What we have ended up with is our original df back but instead of being randomly set with times and dates, it is now uniformly homogenously sampled, one a day at midnight.

# %%
# Let's plot the data once more, to see how we're doing
daily_data.plot(figsize=(15, 4), style=".")

# %% [markdown]
# Now where there were gaps we now have an estimate from interpolate as to what those values should be. Only problem is, those gaps were when no one was there to drink coffees, so the data that we have now, is totally manufactured and do not represent what happened in the real world...is that what has happened?

# %% [markdown]
# #### Let's begin by figuring out how many coffees are made on any given day
# How many coffees were there today? That's just how many coffees there are today minus the amount that there were yesterday...

# %%
#Not sure why we are doing this...
coffees_by_day = daily_data.groupby('weekdays').mean()
coffees_by_day
# Out:
#                coffees
# weekdays
# Friday     9041.387848
# Monday     9107.593954
# Saturday   9075.525882
# Sunday     9091.825740
# Thursday   8997.887023
# Tuesday    9027.274897
# Wednesday  9066.407862

# %% [markdown]
# We are going to use ``.diff()`` on the coffee column and then we are going to follow up with a ``.shift()``

# %%
coffees_made = daily_data.coffees.diff().shift(-1)
coffees_made.head()

# Add this as a column to the dataframe
#daily_data["coffees_made_today"] = coffees_made

#daily_data.head()
# Out:
# 2011-10-03          NaN
# 2011-10-04    34.255987
# 2011-10-05    55.402049
# 2011-10-06    78.778013
# 2011-10-07    64.392941
# Freq: D, Name: coffees, dtype: float64

# %% [markdown]
# ``.diff`` - Just looks at the difference between any two rows
# We are looking at the difference between the one cell and the previous one and putting the difference into the next cell below
# ``.shift(-1)`` - To move everything up by one.
# - His data contained an NaN for 04/10/2011 that it shouldn't have. That's whay we used the ``.shift()`` method
# - These figures tell us that on the 4th, 34 coffees were made and on the 5th, 55 coffees were made
#
# **Let's add that as a column**

# %%
daily_data['coffees_made_today'] = coffees_made
daily_data.head()
# Out:
#                coffees   weekdays  coffees_made_today
# 2011-10-03         NaN     Monday                 NaN
# 2011-10-04  404.408262    Tuesday           34.255987
# 2011-10-05  438.664249  Wednesday           55.402049
# 2011-10-06  494.066298   Thursday           78.778013
# 2011-10-07  572.844311     Friday           64.392941

# %% [markdown]
# **Now we can group this**<br>
# We are going to group by weekdays

# %%
# This is a repeat of the stuff that we did a few cells ago

# .groupby weekdays, take the mean and grab the coffees_made_today column
coffees_by_day = daily_data.groupby('weekdays').mean()
coffees_by_day
# Out:
#                coffees  coffees_made_today
# weekdays
# Friday     9041.387848           34.138034
# Monday     9107.593954           37.802404
# Saturday   9075.525882           16.299858
# Sunday     9091.825740           15.768215
# Thursday   8997.887023           43.500824
# Tuesday    9027.274897           39.132964
# Wednesday  9066.407862           47.640057

# %% [markdown]
# We take the mean to tell us how many coffees were made on the average day<br>
# **Let's order this Series and then plot it...**

# %%
# Sort coffees_by_day by our list of weekday names
coffees_by_day = coffees_by_day.loc[weekday_names]

# Plot a bar chart
coffees_by_day['coffees_made_today'].plot(kind="bar", rot = 45)

# %% [markdown]
# ## 3. Coffee per person
# #### We can now pull in data on how many people were in the department

# %%
# Bring in data/department_members.csv;
# have the first column be the index, and parse the dates
people = pd.read_csv("data/department_members.csv", index_col=[0], parse_dates=True)

people.head() # At the end of August there were 12 people etc
# Out:
#             members
# date
# 2011-08-31       12
# 2011-09-30       14
# 2011-10-31       14
# 2011-11-30       14
# 2011-12-31       15

# %% [markdown]
# #### Let's join the datasets.
# How do we join something that's monthly to our dataset that's daily? Firstly, we are going to do an outer join.<br>
# **How join works**
# - A join looks at two datasets, it's going to compare one of the columns that you are telling it to look at, usually that'll be the index but you can tell it to look at anything.
# - You then say, wherever these indices match extend that row
# - The default in Pandas is an inner join
#     - If my first dataset has an index which doesn't appear in my second dataset - drop that row!
# - An outer join does the opposite
#     - If this one has an index and this one hasn't, keep that row and just fill it with NaN's
#
# **Note :** by default, inner joins are performed. That is, if a row from one of the datasets has an index that isn't in the other dataset, that row is dropped. You can specify whether you want outer, left, or right joins, as well plenty of other useful options. The `pandas` API for joining or [merging](https://pandas.pydata.org/pandas-docs/stable/merging.html) datasets is very developed.

# %%
#This is what the outer join looks like...
daily_data.join(people, how="outer")
# Out:
#                  coffees   weekdays  coffees_made_today  members
# 2011-08-31           NaN        NaN                 NaN     12.0
# 2011-09-30           NaN        NaN                 NaN     14.0
# 2011-10-03           NaN     Monday                 NaN      NaN
# 2011-10-04    404.408262    Tuesday           34.255987      NaN
# 2011-10-05    438.664249  Wednesday           55.402049      NaN
# 2011-10-06    494.066298   Thursday           78.778013      NaN
# 2011-10-07    572.844311     Friday           64.392941      NaN
# 2011-10-08    637.237253   Saturday            7.492196      NaN
# 2011-10-09    644.729448     Sunday            8.195209      NaN
# 2011-10-10    652.924658     Monday           81.648549      NaN
# 2011-10-11    734.573206    Tuesday           46.351008      NaN
# 2011-10-12    780.924214  Wednesday           71.254295      NaN
# 2011-10-13    852.178510   Thursday           76.057819      NaN
# ...

# %% [markdown]
# Let's take the 31/08/2011 entry to explain what join has done here. The daily_data df has no data for this date so we see a row of NaN's from that dataset. The people df says that there were 12 members of the dept. So although we do not start recording the number of coffees until 3/10/11 (from daily_data), we see that the other df is supplying data. Hence we have 3 x NaN and one piece of useful data<br>
# For more information, have a look at the Pandas' docs on [Merge, Join & Concatenate](https://pandas.pydata.org/pandas-docs/stable/merging.html)
#
# Now we are going to interpolate over the members column because we have a bunch of NaNs which we don't like...we wanna fill those in...

# %%
# Use an outer join, then interpolate over missing values using nearest values
daily_data = daily_data.join(people, how="outer").interpolate(method="nearest")

daily_data.head()
# Out:
#                coffees   weekdays  coffees_made_today  members
# 2011-08-31         NaN        NaN                 NaN     12.0
# 2011-09-30         NaN        NaN                 NaN     14.0
# 2011-10-03         NaN     Monday                 NaN     14.0
# 2011-10-04  404.408262    Tuesday           34.255987     14.0
# 2011-10-05  438.664249  Wednesday           55.402049     14.0

# %% [markdown]
# **NOTE:** The above code although in the JN for the lecture is not the same code as on the video. The code on the video looks slightly different...``daily_data = daily_data.interpolate(method = 'nearest')``...not sure if this makes any difference but ther you are.

# %% [markdown]
# #### Let's create a column for the number of coffees consumed per person

# %%
# New column is the ratio of coffees made on a given day to number of members in the department
daily_data["coffees_per_person"] = daily_data.coffees_made_today / daily_data.members

# Let's drop those remaining NaNs while we're at it
#daily_data.dropna(inplace=True)

daily_data.head()
# Out:
#                coffees   weekdays  coffees_made_today  members  \
# 2011-08-31         NaN        NaN                 NaN     12.0
# 2011-09-30         NaN        NaN                 NaN     14.0
# 2011-10-03         NaN     Monday                 NaN     14.0
# 2011-10-04  404.408262    Tuesday           34.255987     14.0
# 2011-10-05  438.664249  Wednesday           55.402049     14.0
#
#             coffees_per_person
# 2011-08-31                 NaN
# 2011-09-30                 NaN
# 2011-10-03                 NaN
# 2011-10-04            2.446856
# 2011-10-05            3.957289

# %% [markdown]
# This is not the number of coffees per person! This is just an avaerage given the data and the number of people in the dept., you may well have people who do not drink any coffee at all and people who drink more than they should...it is an average not a true figure

# %% [markdown]
# #### We can now plot this column

# %%
# Plot the coffees_per_person column
daily_data.coffees_per_person.plot()

# %% [markdown]
# - The huge up and downs are being caused by the drop in consumption over the weekends...it's hard to see but that's what it is
# - The plateaus at the bottom is where the machine was broken and didn't make any coffees at all!

# %% [markdown]
# **Those are strange plateaus. We'll pull in another dataset, telling us when the machine was broken**

# %%
# pd.read_csv(); try using data/coffee_status.csv
# parse_dates as kwarg; also pass index_col
machine_status = pd.read_csv("data/coffee_status.csv", parse_dates=["date"], index_col="date")

machine_status.head()
# Out:
#            status
# date
# 2011-09-16     OK
# 2011-09-17     OK
# 2011-09-18     OK
# 2011-09-19     OK
# 2011-09-20     OK

# %% [markdown]
# **Note :** the ``parse_dates`` keyword argument takes several values. By passing in a list of strings, we're telling ``pandas`` to attempt to parse the dates in columns with those names.
#
# You can read more about the pandas.read_csv() method [here](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html)

# %% [markdown]
# #### What values are in the `status` column?

# %%
# .value_counts()
machine_status.status.value_counts()
# Out:
# OK        514
# BROKEN     88
# Name: status, dtype: int64

# %% [markdown]
# The machine was broken on 88 days

# %% [markdown]
# #### A quick trick to plot this as a time-series...

# %%
# Make a pd.Series from the status series where things are OK
numerical_status = machine_status.status == "OK"

numerical_status
# Out:
# date
# 2011-09-16    True
# 2011-09-17    True
# 2011-09-18    True
# 2011-09-19    True
# 2011-09-20    True
# 2011-09-21    True
# 2011-09-22    True
# 2011-09-23    True
# 2011-09-24    True
# 2011-09-25    True
# 2011-09-26    True
# 2011-09-27    True
# 2011-09-28    True
# 2011-09-29    True
# 2011-09-30    True
# 2011-10-01    True
# 2011-10-02    True
# 2011-10-03    True
# 2011-10-04    True
# 2011-10-05    True
# 2011-10-06    True
# 2011-10-07    True
# 2011-10-08    True
# 2011-10-09    True
# 2011-10-10    True
# 2011-10-11    True
# 2011-10-12    True
# 2011-10-13    True
# 2011-10-14    True
# 2011-10-15    True
#               ...
# 2013-04-10    True
# 2013-04-11    True
# 2013-04-12    True
# 2013-04-13    True
# 2013-04-14    True
# 2013-04-15    True
# 2013-04-16    True
# 2013-04-17    True
# 2013-04-18    True
# 2013-04-19    True
# 2013-04-20    True
# 2013-04-21    True
# 2013-04-22    True
# 2013-04-23    True
# 2013-04-24    True
# 2013-04-25    True
# ...

# %% [markdown]
# **Note :** the first line here creates a boolean `pd.Series`, holding the value `True` when `machine_status.status` is `"OK"`, and `False` otherwise. Because it's a `pd.Series`, its index stays the same as that of `machine_status`, which was a `DatetimeIndex`. Then, we can plot the boolean series ( `True` appearing as `1`, and `False` appearing as `0` ), and just quickly scan to see that there are long areas where the coffee machine was operations, with short bouts ( thankfully ! ) of the machine being broken....now to try to plot that...

# %% [markdown]
# ``numerical_status.plot()`` - I get ``Empty 'DataFrame': no numeric data to plot`` when I try to plot this and since I cannot see where I went wrong, I am going to have to move on

# %% [markdown]
# #### Let's join the datasets on the date field !

# %%
# .join()
daily_data = daily_data.join(machine_status)

daily_data.head()
# Out:
#                coffees   weekdays  coffees_made_today  members  \
# 2011-08-31         NaN        NaN                 NaN     12.0
# 2011-09-30         NaN        NaN                 NaN     14.0
# 2011-10-03         NaN     Monday                 NaN     14.0
# 2011-10-04  404.408262    Tuesday           34.255987     14.0
# 2011-10-05  438.664249  Wednesday           55.402049     14.0
#
#             coffees_per_person status
# 2011-08-31                 NaN    NaN
# 2011-09-30                 NaN     OK
# 2011-10-03                 NaN     OK
# 2011-10-04            2.446856     OK
# 2011-10-05            3.957289     OK

# %% [markdown]
# #### We'll bring in this numerical representation of status column into our dataframe too

# %%
# Column depicting when the status was "OK"
# Cast the series to ints before as you create a new column in the dataframe
daily_data["numerical_status"] = (daily_data.status == "OK").astype(int)

daily_data.head()
# Out:
#                coffees   weekdays  coffees_made_today  members  \
# 2011-08-31         NaN        NaN                 NaN     12.0
# 2011-09-30         NaN        NaN                 NaN     14.0
# 2011-10-03         NaN     Monday                 NaN     14.0
# 2011-10-04  404.408262    Tuesday           34.255987     14.0
# 2011-10-05  438.664249  Wednesday           55.402049     14.0
#
#             coffees_per_person status  numerical_status
# 2011-08-31                 NaN    NaN                 0
# 2011-09-30                 NaN     OK                 1
# 2011-10-03                 NaN     OK                 1
# 2011-10-04            2.446856     OK                 1
# 2011-10-05            3.957289     OK                 1

# %% [markdown]
# #### Let's plot both the coffees per person and the numerical status

# %%
daily_data.plot()

# %% [markdown]
# The number of coffees made to date is overpowering everything so we are going to plot both columns...

# %%
# Plot both columns on the same graph, we pass the index a list of the columns that we want to plot, using default args
daily_data[["coffees_per_person", "numerical_status"]].plot()

# %% [markdown]
# #### We see a strong weekday-weekend effect. Resampling weekly will fix that
# Resampling weekly is going to say, create a bin for every week and for every data point that falls within that week, group it into that bin. We then take the mean of all of those points that fall into those weekly bins

# %%
# Resample weekly, taking the mean of each week to get a weekly value
weekly_data = daily_data.resample("W").mean()

weekly_data[["coffees_made_today", "numerical_status"]].plot()

# %% [markdown]
# The code is fine but our graph looks totally different to his<br>
# ![Coffees Made Today](images/madetoday.png)

# %%
# Resample weekly, taking the mean of each week to get a weekly value
weekly_data = daily_data.resample("W").mean()

weekly_data[["coffees_per_person", "numerical_status"]].plot()

# %% [markdown]
# ## What have we achieved?
# #### Cleaning
#
# - Cast columns to the correct dtypes
# - Dropped rows with no data
# - Truncated the time-series when things got sparse
#
# #### Exploring the contributions
#
# - Discovered who contributed to the dataset and how much
# - Established how contributions varied by day of the week
#
# #### Exploring the time-series
#
# - Resampled the uneven time-series to regular daily intervals
# - Interpolated over missing data using our time index
# - Discovered on what days of the week coffee was especially popular
# - Joined the dataset with others to enrich the information available
# - Derived new columns from existing ones
# - Smoothed the time-series by weekly downsampling
#
# #### Insights
#
# - A small number of people contributed most of the data
# - Contributions were lacking at the weekends, and Mondays had the most contributions
# - Seminar Wednesdays is a strong driver of coffee consumption
# - Periods of low coffee drinking correlated strongly with periods where the machine was broken
# - A significant dip in consumption occurred in the summer months
